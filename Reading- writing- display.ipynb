# %%
pip install opencv-python
# Out:
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img = cv2.imread('D:/images.jpeg')
#img2 = cv2.imread('D:/Europ/taly\Datrix/ssignmnet/stm-data/stm-data/Train/0001_molecules2.npy')

cv2.imshow('it is a cow', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(type(img))
#type(img2)
print (img.shape)
cv2.imwrite('images1.jpg', img)
#cv2.imwrite('images1.png', img)
# Out:
# <class 'numpy.ndarray'>
# (359, 640, 3)
# True

# %%
plt.imshow(img)

# %%
plt.imshow(img[...,::-1])

# %%
#method2
rgb_image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_image)

# %%
import cv2 

img = cv2.imread('D:/images.jpeg')
img[200:400,100:400,:] = 255
plt.imshow(img[...,::-1])

# %%
img[200:300,300:500,:] = (0, 0, 255)
plt.imshow(img[...,::-1])

# %% [markdown]
# Cropping

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('D:/images.jpeg')
plt.imshow(image[...,::-1])

# %%
height, width = image.shape[:2]

# Simply use indexing to crop out the rectangle we desire
cropped = image[150:250 , 50:100]

plt.imshow(cropped[...,::-1])

# %%
cv2.imshow("original", image)
cv2.imshow("cropped", cropped)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
height, width = image.shape[:2]

# Simply use indexing to crop out the rectangle we desire
cropped = image[150:250 , 50:100]

plt.imshow(cropped[...,::-1])
